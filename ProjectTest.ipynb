# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/Tik Chung/Desktop/Cloud_Computing_Project/yellow_tripdata_2020-01.csv',sep=",", encoding='utf-8')
# Out:
# c:\users\tik chung\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
len(df)
# Out:
# 6405008

# %%
df1 = pd.read_csv('/Users/Tik Chung/Desktop/Cloud_Computing_Project/green_tripdata_2020-01.csv',sep=",", encoding='utf-8')
# Out:
# c:\users\tik chung\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
len(df1)
# Out:
# 447770

# %%
df01 = pd.concat([df,df1])

# %%
df01.head(10)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1       1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2       1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3       1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4       2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# 5       2.0  2020-01-01 00:09:44   2020-01-01 00:10:37              1.0
# 6       2.0  2020-01-01 00:39:25   2020-01-01 00:39:29              1.0
# 7       2.0  2019-12-18 15:27:49   2019-12-18 15:28:59              1.0
# 8       2.0  2019-12-18 15:30:35   2019-12-18 15:31:35              4.0
# 9       1.0  2020-01-01 00:29:01   2020-01-01 00:40:28              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.20         1.0                  N           238           239
# ...

# %%
len(df01)
# Out:
# 6852778

# %%
df01 = df01.drop(columns=['VendorID','tpep_pickup_datetime','tpep_dropoff_datetime','lpep_pickup_datetime','lpep_dropoff_datetime'])

# %%
df01.head(10)
# Out:
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0           1.20         1.0                  N
# 1              1.0           1.20         1.0                  N
# 2              1.0           0.60         1.0                  N
# 3              1.0           0.80         1.0                  N
# 4              1.0           0.00         1.0                  N
# 5              1.0           0.03         1.0                  N
# 6              1.0           0.00         1.0                  N
# 7              1.0           0.00         5.0                  N
# 8              4.0           0.00         1.0                  N
# 9              2.0           0.70         1.0                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           238           239           1.0         6.00    3.0      0.5
# 1           239           238           1.0         7.00    3.0      0.5
# ...

# %%
df2 = pd.read_csv('/Users/Tik Chung/Desktop/Cloud_Computing_Project/fhvhv_tripdata_2020-01.csv',sep=",", encoding='utf-8')

# %%
df3 = pd.read_csv('/Users/Tik Chung/Desktop/Cloud_Computing_Project/fhv_tripdata_2020-01.csv',sep=",", encoding='utf-8')

# %%
df23 = pd.concat([df2,df3])

# %%
replace_num = {"hvfhs_license_num": {'HV0002':'Juno', 'HV0003':'Uber', 'HV0004':'Via', 'HV0005':'Lyft'}}
replace_num
# Out:
# {'hvfhs_license_num': {'HV0002': 'Juno',
#   'HV0003': 'Uber',
#   'HV0004': 'Via',
#   'HV0005': 'Lyft'}}

# %%
df23 = df23.replace(replace_num)
df23.head(10)
# Out:
#   hvfhs_license_num dispatching_base_num      pickup_datetime  \
# 0              Uber               B02864  2020-01-01 00:45:34
# 1              Uber               B02682  2020-01-01 00:47:50
# 2              Uber               B02764  2020-01-01 00:04:37
# 3              Uber               B02764  2020-01-01 00:26:36
# 4              Uber               B02764  2020-01-01 00:37:49
# 5              Uber               B02764  2020-01-01 00:49:23
# 6              Uber               B02870  2020-01-01 00:21:11
# 7              Uber               B02870  2020-01-01 00:38:28
# 8              Uber               B02870  2020-01-01 00:46:26
# 9              Uber               B02836  2020-01-01 00:15:35
#
#       dropoff_datetime  PULocationID  DOLocationID  SR_Flag
# 0  2020-01-01 01:02:20         148.0          90.0      NaN
# 1  2020-01-01 00:53:23         114.0          79.0      NaN
# 2  2020-01-01 00:21:49           4.0         125.0      NaN
# ...

# %%
df23 = df23.drop(columns=['pickup_datetime','dropoff_datetime'])
df23
# Out:
#         hvfhs_license_num dispatching_base_num  PULocationID  DOLocationID  \
# 0                    Uber               B02864         148.0          90.0
# 1                    Uber               B02682         114.0          79.0
# 2                    Uber               B02764           4.0         125.0
# 3                    Uber               B02764         231.0         113.0
# 4                    Uber               B02764         114.0         144.0
# ...                   ...                  ...           ...           ...
# 1958931               NaN               B03266         223.0         223.0
# 1958932               NaN               B03266         193.0          56.0
# 1958933               NaN               B03266           7.0           7.0
# 1958934               NaN               B03266           7.0           7.0
# 1958935               NaN               B03266         223.0         223.0
#
#          SR_Flag
# 0            NaN
# 1            NaN
# ...

# %%
finaldf = pd.concat([df01,df23])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-17-b61aba39a5f1> in <module>
# ----> 1 finaldf = pd.concat([df01,df23])
#
# c:\users\tik chung\appdata\local\programs\python\python38\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# c:\users\tik chung\appdata\local\programs\python\python38\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     494                 mgrs_indexers.append((obj._data, indexers))
#     495
# --> 496             new_data = concatenate_block_managers(
#     497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#
# ...

# %%
len(df01)
# Out:
# 183283
